# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import glob
import os

all_files = glob.glob("Harga Bahan Pangan/train/*")
all_files
# Out:
# []

# %%
all_df = pd.DataFrame({"Date": []})

for file in all_files:
    df = pd.read_csv(file)
    print(df)
# Out:
#             Date     Aceh     Bali   Banten  Bengkulu  DI Yogyakarta  \
# 0     2022-01-01      NaN      NaN      NaN       NaN            NaN
# 1     2022-01-02      NaN      NaN      NaN       NaN            NaN
# 2     2022-01-03      NaN      NaN      NaN       NaN            NaN
# 3     2022-01-04      NaN      NaN      NaN       NaN            NaN
# 4     2022-01-05      NaN      NaN      NaN       NaN            NaN
# ...          ...      ...      ...      ...       ...            ...
# 999   2024-09-26  15660.0  16210.0  14900.0   16100.0        16280.0
# 1000  2024-09-27  15720.0  16430.0  15950.0   16100.0        16300.0
# 1001  2024-09-28  15730.0  16510.0  15710.0   16100.0        15410.0
# 1002  2024-09-29  15610.0  16410.0  15680.0   16100.0        16280.0
# 1003  2024-09-30  15670.0  16340.0  15710.0   16100.0        16280.0
#
#       DKI Jakarta  Gorontalo    Jambi  Jawa Barat  ...    Papua     Riau  \
# ...
